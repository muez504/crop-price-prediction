# %%
import numpy as np# Importing every library we need

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
df = pd.read_csv("datasets.csv")

# %%
df.head()# shows the first five rows with all colmuns by default
# Out:
#     market place           Crop Variety  producer min  producer max  many min  \
# 0    Adet Gebeya   White Teff (Quintal)        2050.0        2200.0         0
# 1    Adet Gebeya   Mixed Teff (Quintal)        1850.0        2000.0         0
# 2    Adet Gebeya     Red Teff (Quintal)        1700.0        1800.0         0
# 3  Bichena Gebeya    Red Teff (Quintal)        1830.0        1850.0         0
# 4  Bichena Gebeya  White Teff (Quintal)        2200.0        2400.0         0
#
#    many max  single min  single max      amount collection date
# 0         0      2100.0      2250.0  Sufficient        4/1/2019
# 1         0      1900.0      2050.0  Sufficient        4/1/2019
# 2         0      1800.0      1850.0       Under        4/1/2019
# 3         0      1890.0      1960.0  Sufficient        4/2/2019
# 4         0      2250.0      2520.0  Sufficient        4/2/2019

# %%
df.info()#tells the number of rows and colmuns of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60627 entries, 0 to 60626
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   market place     60627 non-null  object
#  1   Crop Variety     60627 non-null  object
#  2   producer min     60627 non-null  float64
#  3   producer max     60627 non-null  float64
#  4   many min         60627 non-null  int64
#  5   many max         60627 non-null  int64
#  6   single min       60627 non-null  float64
#  7   single max       60627 non-null  float64
#  8   amount           60627 non-null  object
#  9   collection date  60627 non-null  object
# dtypes: float64(4), int64(2), object(4)
# memory usage: 4.6+ MB

# %%
df.isnull().sum()# do we have empty or null value in the data ? 1 for yes 0 for no
# Out:
# market place       0
# Crop Variety       0
# producer min       0
# producer max       0
# many min           0
# many max           0
# single min         0
# single max         0
# amount             0
# collection date    0
# dtype: int64

# %%
df.head(100)# trying to print 100 rows of te data
# Out:
#           market place           Crop Variety  producer min  producer max  \
# 0          Adet Gebeya   White Teff (Quintal)        2050.0        2200.0
# 1          Adet Gebeya   Mixed Teff (Quintal)        1850.0        2000.0
# 2          Adet Gebeya     Red Teff (Quintal)        1700.0        1800.0
# 3        Bichena Gebeya    Red Teff (Quintal)        1830.0        1850.0
# 4        Bichena Gebeya  White Teff (Quintal)        2200.0        2400.0
# ..                  ...                   ...           ...           ...
# 95  Debere Elias Gebeya    Red Teff (Quintal)        1650.0        1700.0
# 96        Wolaita Soddo  White Teff (Quintal)           0.0           0.0
# 97        Wolaita Soddo    Red Teff (Quintal)           0.0           0.0
# 98        Wolaita Soddo  Mixed Teff (Quintal)           0.0           0.0
# 99             Hawassa   White Teff (Quintal)           0.0           0.0
#
#     many min  many max  single min  single max      amount collection date
# ...

# %%
df.columns# to see the columns of the data
# Out:
# Index(['market place ', 'Crop Variety', 'producer min', 'producer max',
#        'many min', 'many max', 'single min', 'single max', 'amount',
#        'collection date'],
#       dtype='object')

# %%
data2 = df.copy()#incase something happends copy it to anothe store

# %%
data2 = data2.dropna()#if there was an empty row in the previos it would totally romove the row

# %%
data2.head(10)
# Out:
#           market place           Crop Variety  producer min  producer max  \
# 0          Adet Gebeya   White Teff (Quintal)        2050.0        2200.0
# 1          Adet Gebeya   Mixed Teff (Quintal)        1850.0        2000.0
# 2          Adet Gebeya     Red Teff (Quintal)        1700.0        1800.0
# 3        Bichena Gebeya    Red Teff (Quintal)        1830.0        1850.0
# 4        Bichena Gebeya  White Teff (Quintal)        2200.0        2400.0
# 5        Bichena Gebeya  Mixed Teff (Quintal)        2000.0        2100.0
# 6  Kokit  Metema Gebeya  White Teff (Quintal)           0.0           0.0
# 7  Kokit  Metema Gebeya    Red Teff (Quintal)        1800.0        1900.0
# 8   Debere Elias Gebeya  White Teff (Quintal)        2150.0        2200.0
# 9  Kokit  Metema Gebeya  Mixed Teff (Quintal)           0.0           0.0
#
#    many min  many max  single min  single max      amount collection date
# 0         0         0      2100.0      2250.0  Sufficient        4/1/2019
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60627 entries, 0 to 60626
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   market place     60627 non-null  object
#  1   Crop Variety     60627 non-null  object
#  2   producer min     60627 non-null  float64
#  3   producer max     60627 non-null  float64
#  4   many min         60627 non-null  int64
#  5   many max         60627 non-null  int64
#  6   single min       60627 non-null  float64
#  7   single max       60627 non-null  float64
#  8   amount           60627 non-null  object
#  9   collection date  60627 non-null  object
# dtypes: float64(4), int64(2), object(4)
# memory usage: 4.6+ MB

# %%
data2.head(50)
# Out:
#                  market place             Crop Variety  producer min  \
# 0                 Adet Gebeya     White Teff (Quintal)        2050.0
# 1                 Adet Gebeya     Mixed Teff (Quintal)        1850.0
# 2                 Adet Gebeya       Red Teff (Quintal)        1700.0
# 3               Bichena Gebeya      Red Teff (Quintal)        1830.0
# 4               Bichena Gebeya    White Teff (Quintal)        2200.0
# 5               Bichena Gebeya    Mixed Teff (Quintal)        2000.0
# 6         Kokit  Metema Gebeya    White Teff (Quintal)           0.0
# 7         Kokit  Metema Gebeya      Red Teff (Quintal)        1800.0
# 8          Debere Elias Gebeya    White Teff (Quintal)        2150.0
# 9         Kokit  Metema Gebeya    Mixed Teff (Quintal)           0.0
# 10        Kokit  Metema Gebeya  White Sesame (Quintal)        4600.0
# 11         Debere Elias Gebeya    Mixed Teff (Quintal)        1750.0
# 12         Debere Elias Gebeya      Red Teff (Quintal)        1650.0
# ...

# %%
data2.isnull()
# Out:
#        market place   Crop Variety  producer min  producer max  many min  \
# 0              False         False         False         False     False
# 1              False         False         False         False     False
# 2              False         False         False         False     False
# 3              False         False         False         False     False
# 4              False         False         False         False     False
# ...              ...           ...           ...           ...       ...
# 60622          False         False         False         False     False
# 60623          False         False         False         False     False
# 60624          False         False         False         False     False
# 60625          False         False         False         False     False
# 60626          False         False         False         False     False
#
#        many max  single min  single max  amount  collection date
# ...

# %%
data2.columns
# Out:
# Index(['market place ', 'Crop Variety', 'producer min', 'producer max',
#        'many min', 'many max', 'single min', 'single max', 'amount',
#        'collection date'],
#       dtype='object')
